# %%
import numpy as np
#Q.1 For the array gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]'), Find
#i. Sum of all elements

gfg=np.matrix('[4,1,9;12,3,1;4,5,6]')
print(np.sum(gfg))

#ii. Sum of all elements row-wise

print(np.sum(gfg,axis=1))

#iii. Sum of all elements column-wise

print(np.sum(gfg,axis=0))
# Out:
# 45
# [[14]
#  [16]
#  [15]]
# [[20  9 16]]

# %%
#Q.2 (a)For the array: array = np.array([10, 52, 62, 16, 16, 54, 453]), find
#i. Sorted array
array=np.array([10,52,62,16,16,54,453])
print("Sorted Array:",np.sort(array))

#ii. Indices of sorted array
print("Indices of Sorted Array:",np.argsort(array))

#iii. 4 smallest elements
print("4 Smallest Elements:",np.sort(array)[:4])

#iv. 5 largest elements
print("5 Largest Elements:",np.sort(array)[-5:])

#(b) For the array: array = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0]), find
#i. Integer elements only
array=np.array([1.0,1.2,2.2,2.0,3.0,2.0])
print("Integer Elements:",array[array==array.astype(int)])

#ii. Float elements only
print("Float Elements:",array[array!=array.astype(int)])
# Out:
# Sorted Array: [ 10  16  16  52  54  62 453]
# Indices of Sorted Array: [0 3 4 1 5 2 6]
# 4 Smallest Elements: [10 16 16 52]
# 5 Largest Elements: [ 16  52  54  62 453]
# Integer Elements: [1. 2. 3. 2.]
# Float Elements: [1.2 2.2]

# %%
#Q.3 You are given a weekly sales dataset and need to perform various operations using NumPy broadcasting.
#a) Generate your unique sales dataset:
#Take the sum of the ASCII values of the initials of your first and last name. Call this value X. (If your initials are A B → ASCII sum = 65 + 66 = 131 → sales = [131, 181, 231, 281, 331].) Create a NumPy array sales with values [X, X+50, X+100, X+150,X+200].

initials="SD"
X=sum(ord(char)for char in initials)
sales=np.array([X,X+50,X+100,X+150,X+200])

#b) Compute your personalized tax rate as ((X % 5) + 5) / 100.Use broadcasting to apply this tax rate to each sales value.

tax_rate=((X%5)+5)/100
taxed_sales=sales*(1-tax_rate)
print("Taxed Sales:",taxed_sales)

#c) Adjust sales based on discount:
# If sales < X+100, apply a 5% discount.
# If sales >= X+100, apply a 10% discount.

discounted_sales=np.where(sales<X+100,sales*0.95,sales*0.90)
print("Discounted Sales:",discounted_sales)

#d) Expand sales data for multiple weeks:
# Create a 3×5 matrix representing three weeks of sales by stacking sales three times using broadcasting.
# Increase sales by 2% per week using element-wise broadcasting.

weekly_sales=np.tile(sales,(3,1))
weekly_sales=weekly_sales*(1+np.arange(3).reshape(3,1)*0.02)
print("Weekly Sales with 2% Growth:\n",weekly_sales)
# Out:
# Taxed Sales: [141.94 188.94 235.94 282.94 329.94]
# Discounted Sales: [143.45 190.95 225.9  270.9  315.9 ]
# Weekly Sales with 2% Growth:
#  [[151.   201.   251.   301.   351.  ]
#  [154.02 205.02 256.02 307.02 358.02]
#  [157.04 209.04 261.04 313.04 365.04]]

# %%
import matplotlib.pyplot as plt
#Q4. Generate x values using np.linspace() from -10 to 10 with 100 points. Use each function from the list below and compute y values using NumPy:
#Y = x2
plt.figure(figsize=(10,8))

plt.subplot(2,2,1)
plt.plot(x,y1,color='b')
plt.title("y=x²")
plt.xlabel("x values")
plt.ylabel("y values")
plt.grid(True)

#Plot the chosen function using Matplotlib. Add title, labels, and grid for clarity.

# %%
# Y = sin(x)
plt.subplot(2,2,2)
plt.plot(x,y2,color='r')
plt.title("y=sin(x)")
plt.xlabel("x values")
plt.ylabel("y values")
plt.grid(True)

# %%
# Y = ex
plt.subplot(2,2,3)
plt.plot(x,y3,color='g')
plt.title("y=e^x")
plt.xlabel("x values")
plt.ylabel("y values")
plt.grid(True)

# %%
# Y = log(|x| + 1)

plt.subplot(2,2,4)
plt.plot(x,y4,color='m')
plt.title("y=log(|x|+1)")
plt.xlabel("x values")
plt.ylabel("y values")
plt.grid(True)
